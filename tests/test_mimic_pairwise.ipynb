# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parents[0] / "src"))

# %%
from datetime import datetime
from pathlib import Path

from viberank.datasets.mimic_pairwise_dataloader import MIMICPairwiseDataLoader
from viberank.experiments.pairwise_comparisons import PairwiseExperimentRunner
from viberank.utils.logging import JSONLResponseLogger
from viberank.comparators.dummy import DummyComparator

# %%
config_path = Path("../configs/datasets/mimic_pairwise.yaml")
dataloader = MIMICPairwiseDataLoader.from_yaml(config_path)
dataloader.prepare()

run_id = datetime.now().strftime("dummy_vispdat_%Y%m%d_%H%M%S")
log_path = dataloader.config.responses_dir / f"{run_id}.jsonl"

logger = JSONLResponseLogger(
    log_path=log_path,
    flush_every=1,
    store_prompts=True,
)

# %%
dataloader.get_comparator_kwargs()
# Out:
# {'items': ['31128182',
#   '33831108',
#   '30366890',
#   '31512440',
#   '30771762',
#   '34056271',
#   '36312788',
#   '38635725',
#   '33968379',
#   '38962720'],
#  'data_folder': PosixPath('/Users/gaurabpokharel/Library/CloudStorage/Box-Box/WashU-ICA-SFT-Working Folder - shared/Sandboxes/Gaurab Pokharel/VibeRank/raw/mimic/mimic_triage/responses/_selected_jsons'),
#  'prompt_path': PosixPath('/Users/gaurabpokharel/Library/CloudStorage/Box-Box/WashU-ICA-SFT-Working Folder - shared/Sandboxes/Gaurab Pokharel/VibeRank/raw/mimic/prompt_medical.txt'),
#  'results_folder': PosixPath('/Users/gaurabpokharel/Library/CloudStorage/Box-Box/WashU-ICA-SFT-Working Folder - shared/Sandboxes/Gaurab Pokharel/VibeRank/raw/mimic/mimic_triage/responses')}

# %%
comp_kwargs = dataloader.get_comparator_kwargs()
comparator = DummyComparator(
    items=comp_kwargs["items"],
    data_folder=comp_kwargs["data_folder"],
    prompt_path=comp_kwargs["prompt_path"],
    results_folder=comp_kwargs["results_folder"],
    logger=logger,
    num_samples=10,
    rng_seed=42,
    # true_ranking=None means it generates a random one
)

# %%
runner = PairwiseExperimentRunner(
    dataloader=dataloader,
    logger=logger,
    comparator=comparator,
    run_id="rc_vispdat_dummy_001",
    model_name="dummy",
    prompt_version="v1",
)


result = runner.run()

# %%
result
# Out:
# array([[ 0,  6,  1,  2,  4,  3,  2,  0,  3,  6],
#        [ 4,  0,  0,  2,  1,  2,  4,  0,  1,  5],
#        [ 9, 10,  0,  4,  7,  6,  7,  5,  9,  7],
#        [ 8,  8,  6,  0,  7,  8,  8,  3,  3,  4],
#        [ 6,  9,  3,  3,  0,  2,  5,  1,  2,  4],
#        [ 7,  8,  4,  2,  8,  0,  5,  3,  4,  8],
#        [ 8,  6,  3,  2,  5,  5,  0,  3,  3,  6],
#        [10, 10,  5,  7,  9,  7,  7,  0,  6, 10],
#        [ 7,  9,  1,  7,  8,  6,  7,  4,  0,  6],
#        [ 4,  5,  3,  6,  6,  2,  4,  0,  4,  0]])
